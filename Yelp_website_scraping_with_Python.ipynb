# %%
## import some libraries
import time
import requests,re
from bs4 import BeautifulSoup
import pandas as pd
import json
import numpy as np
import requests
import os
import glob
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import csv

# %% [markdown]
# # Get the URLs of starbuck lists in 10 cities

# %%
## top 10 cities with the most starbucks
city_list = pd.Series(["New York","Chicago","Houston","San Diego","Los Angeles",
             "Seattle","Las Vegas","Portland","Phoenix","San Francisco"])

# %%
## get city url
driver = webdriver.Chrome('/Users/haohao/Desktop/Courses/422 - Data Design & Representation/chromedriver')
def get_url(city):
    time.sleep(5)
    driver.get("https://www.yelp.com/")
    element1 = driver.find_element_by_id("find_desc")
    element1.clear()
    element1.send_keys("Starbucks")

    element2 = driver.find_element_by_id("dropperText_Mast")
    element2.clear()
    element2.send_keys("%s" % city)

    element3 = driver.find_element_by_id("header-search-submit")
    element3.click()
    return(driver.current_url)

url_list = city_list.apply(lambda x: get_url(x))

## save the urls to csv
url_list = pd.DataFrame(url_list)
df.to_csv(r'url_list.csv')

# %%
## open the urls from csv
url_list = pd.read_csv("url_list.csv")['0']

# %%
## change the URLs so that all starbucks stores will show up
url_main_search =url_list.apply(lambda x: re.sub(r'(https://www.yelp.com/search[?])(find_desc=.+)',r'\1choq=1&\2',x))
list(url_main_search)
# Out:
# ['https://www.yelp.com/search?choq=1&find_desc=Starbucks&find_loc=New+York&ns=1',
#  'https://www.yelp.com/search?choq=1&find_desc=Starbucks&find_loc=Chicago&ns=1',
#  'https://www.yelp.com/search?choq=1&find_desc=Starbucks&find_loc=Houston&ns=1',
#  'https://www.yelp.com/search?choq=1&find_desc=Starbucks&find_loc=San+Diego&ns=1',
#  'https://www.yelp.com/search?choq=1&find_desc=Starbucks&find_loc=Los+Angeles&ns=1',
#  'https://www.yelp.com/search?choq=1&find_desc=Starbucks&find_loc=Seattle&ns=1',
#  'https://www.yelp.com/search?choq=1&find_desc=Starbucks&find_loc=Las+Vegas&ns=1',
#  'https://www.yelp.com/search?choq=1&find_desc=Starbucks&find_loc=Portland&ns=1',
#  'https://www.yelp.com/search?choq=1&find_desc=Starbucks&find_loc=Phoenix&ns=1',
#  'https://www.yelp.com/search?choq=1&find_desc=Starbucks&find_loc=San+Francisco&ns=1']

# %% [markdown]
# # Get the URLs of all starbucks stores

# %%
starbuck_list = list()

kv={'user-agent':'Mozilla/5.0'}
for j in range(len(url_main_search)):
    for i in range(46):
        result = requests.get(url_main_search[j]+"&start="+str(i*10), headers=kv)
        ## parse the content into a BeautifulSoup object
        soup = BeautifulSoup(result.content, 'html.parser')   
        ## find all search items
        search_items = soup.find_all('a', class_="lemon--a__373c0__IEZFH link__373c0__1G70M link-color--inherit__373c0__3dzpk link-size--inherit__373c0__1VFlE")
        ## loop through each item, check if sponsored
        for search_item in search_items:
            link = search_item.get('href')
            if re.match('/biz/starbucks-new-york.*',str(link)):
                starbuck_list.append('https://www.yelp.com'+link)
            elif re.match('/biz/starbucks-chicago.*',str(link)):
                starbuck_list.append('https://www.yelp.com'+link) 
            elif re.match('/biz/starbucks-houston.*',str(link)):
                starbuck_list.append('https://www.yelp.com'+link)
            elif re.match('/biz/starbucks-san-diego.*',str(link)):
                starbuck_list.append('https://www.yelp.com'+link) 
            elif re.match('/biz/starbucks-los-angeles.*',str(link)):
                starbuck_list.append('https://www.yelp.com'+link)
            elif re.match('/biz/starbucks-phoenix.*',str(link)): 
                starbuck_list.append('https://www.yelp.com'+link) 
            elif re.match('/biz/starbucks-seattle.*',str(link)): 
                starbuck_list.append('https://www.yelp.com'+link) 
            elif re.match('/biz/starbucks-las-vegas.*',str(link)): 
                starbuck_list.append('https://www.yelp.com'+link)
            elif re.match('/biz/starbucks-portland.*',str(link)): 
                starbuck_list.append('https://www.yelp.com'+link)
            elif re.match('/biz/starbucks-san-francisco.*',str(link)): 
                starbuck_list.append('https://www.yelp.com'+link)
        time.sleep(2)

# %%
## filter out the closed stores
open_starbuck_list = list()

kv={'user-agent':'Mozilla/5.0'}
for i in range(len(starbuck_list)):
    url = starbuck_list[i]
    result = requests.get(url, headers=kv)
    soup = BeautifulSoup(result.content, 'html.parser') 
    ## whether the store has been closed
    search_closed = soup.find('span', {"class":"lemon--span__373c0__3997G text__373c0__2pB8f text-color--normal__373c0__K_MKN text-align--left__373c0__2pnx_ text-weight--bold__373c0__3HYJa text-size--large__373c0__1568g"})
    if search_closed is None:
        open_starbuck_list.append(url)

# %%
## save the urls to csv
starbuck_list = pd.DataFrame(starbuck_list)
starbuck_list.columns = ['url']
starbuck_list.to_csv(r'starbuck_list.csv')

open_starbuck_list = pd.DataFrame(open_starbuck_list)
open_starbuck_list.columns = ['url']
open_starbuck_list.to_csv(r'open_starbuck_list.csv')

# %%
## open the urls from csv
open_starbuck_list = pd.read_csv("open_starbuck_list.csv")['url']

# %% [markdown]
# # Get the information1 of all starbucks stores
# ### information1: url, name, location, city, zip_code, price, category, score, num_of_review

# %%
def get_info1(opening_stores):
    info1_list = list()
    kv = {'user-agent':'Mozilla/5.0'}
    for i in range(len(opening_stores)):
        url = opening_stores[i]
        result = requests.get(url, headers=kv)
        soup = BeautifulSoup(result.content, 'html.parser') 
        
        ## get store name
        try:
            name = soup.find('h1', {"class":"lemon--h1__373c0__2ZHSL heading--h1__373c0__1VUMO heading--no-spacing__373c0__1PzQP heading--inline__373c0__1F-Z6"}).getText()
        except: 
            name = None
            
        ## get store location,city and zip_code
        try:
            search_location = soup.find_all('p', {"class":"lemon--p__373c0__3Qnnj text__373c0__2pB8f text-color--normal__373c0__K_MKN text-align--left__373c0__2pnx_ text-weight--bold__373c0__3HYJa"})
            if len(search_location)==9:
                location =search_location[0].find("span").getText()
                city_zip = search_location[1].find("span").getText()
            elif len(search_location)==10:
                location =search_location[0].find("span").getText()+' '+search_location[1].find("span").getText()
                city_zip = search_location[2].find("span").getText()
            elif len(search_location)==11:
                location =search_location[0].find("span").getText()+' '+search_location[1].find("span").getText()+' '+search_location[2].find("span").getText()
                city_zip = search_location[3].find("span").getText()
            city = re.sub(r'(.+)(,.+)',r'\1',city_zip)
            zip_code = re.sub(r'(.+)(,.+)(\s)(\d+)',r'\4',city_zip)
        except: 
            location=None
            city = None
            zip_code = None
            
        ## get store price
        try:
            search_price = soup.find('span', {"class":"lemon--span__373c0__3997G text__373c0__2pB8f text-color--normal__373c0__K_MKN text-align--left__373c0__2pnx_ text-bullet--after__373c0__1ZHaA text-size--large__373c0__1568g"})
            price = search_price.getText()[:-1]
        except: price = None
            
        ## get store catrgory
        try:
            search_category = soup.find_all('a', {"class":"lemon--a__373c0__IEZFH link__373c0__29943 link-color--inherit__373c0__15ymx link-size--inherit__373c0__2JXk5"})
            category = search_category[0].getText()
        except: category = None
            
        ## get store score
        try:
            search_score = soup.find('span', {"class":"lemon--span__373c0__3997G display--inline__373c0__1DbOG border-color--default__373c0__2oFDT"})
            score = re.findall(r'\S+',search_score.findChild().get('aria-label'))[0]
        except: score = None
            
        ## get the num of reviews
        try:
            search_num_of_review = soup.find('p', {"class":"lemon--p__373c0__3Qnnj text__373c0__2pB8f text-color--mid__373c0__3G312 text-align--left__373c0__2pnx_ text-size--large__373c0__1568g"})
            num_of_review = re.findall(r'\S+',search_num_of_review.getText())[0]
        except: num_of_review = None
            
        ## combine information of all stores
        time.sleep(1)
        info1_list.append([url, name, location, city, zip_code, price, category, score, num_of_review])
    return(info1_list)

# %%
info1 = get_info1(open_starbuck_list)

# %%
information1 = pd.DataFrame(info1)
information1.columns = ['url','name','location','city','zip_code', 'price', 'category','score', 'num_of_review']

# %% [markdown]
# # Get the information2 of all starbucks stores
# ### information2: url,reviews, review scores, review time, image1, image2, image3

# %%
info2 = list()
kv = {'user-agent':'Mozilla/5.0'}
for i in range(len(open_starbuck_list)):
    url = open_starbuck_list[i]
    result = requests.get(url, headers=kv)
    soup = BeautifulSoup(result.content, 'html.parser') 
    chunks = soup.find_all('div', {"class":"lemon--div__373c0__1mboc arrange-unit__373c0__1piwO arrange-unit-grid-column--8__373c0__2yTAx border-color--default__373c0__2oFDT"})[1:21]
    for chunk in chunks:
        
        ## get the url
        url = url
        
        ## get the review score
        try:
            review_score = re.findall(r'\S+',chunk.find('div',{"role":"img"}).get("aria-label"))[0]
        except: review_score = None
        
        ## get the review time
        try:
            review_time = chunk.find('span', {"class":"lemon--span__373c0__3997G text__373c0__2pB8f text-color--mid__373c0__3G312 text-align--left__373c0__2pnx_"}).getText()
        except: review_time = None
        
        ## get the review content
        try:
            review = chunk.find('span', {"lang":"en"}).getText()
        except: review = None
        
        ## get the top 3 images
        try:
            image1 = chunk.find_all('img',{"class":"lemon--img__373c0__3GQUb photo-box-img__373c0__O0tbt"})[0].get("src")
        except: image1 = None
        try:
            image2 = chunk.find_all('img',{"class":"lemon--img__373c0__3GQUb photo-box-img__373c0__O0tbt"})[1].get("src")
        except: image2 = None
        try:
            image3 = chunk.find_all('img',{"class":"lemon--img__373c0__3GQUb photo-box-img__373c0__O0tbt"})[2].get("src")
        except: image3 = None
        
        ## combine all information
        info2.append([url, review_score, review_time, review, image1, image2, image3])

# %%
information2 = pd.DataFrame(info2)
information2.columns = ['url','review_score','review_time','review_text','image1', 'image2', 'image3']

# %%
## use "city-number" as store_id
for i in range(len(information1)):
    information1['url'][i] = re.sub(r'.*starbucks-(.*)\?.*',r'\1', information1['url'][i])

for i in range(len(information2)):
    information2['url'][i] = re.sub(r'.*starbucks-(.*)\?.*',r'\1', information2['url'][i])

## rename the "url" column to "store_id"
information1 = information1.rename(columns = {'url': 'store_id'})
information1.head()
# Out:
#        store_id       name        location      city  zip_code price  \
# 0  new-york-524        NaN             NaN       NaN       NaN   NaN
# 1  new-york-217  Starbucks     135 John St  New York   10038.0     $
# 2  new-york-567  Starbucks      80 Pine St  New York   10005.0    $$
# 3  new-york-290  Starbucks      99 Wall St  New York   10005.0     $
# 4  new-york-381  Starbucks  100 William St  New York   10038.0    $$
#
#        category  score  num_of_review
# 0           NaN    NaN            NaN
# 1  Coffee & Tea    2.5           47.0
# 2  Coffee & Tea    2.5           28.0
# 3  Coffee & Tea    2.5           39.0
# 4  Coffee & Tea    3.0           31.0

# %%
information2 = information2.rename(columns = {'url': 'store_id'})
information2.head()
# Out:
#        store_id  review_score review_time  \
# 0  new-york-524             2   10/6/2019
# 1  new-york-524             1  10/21/2019
# 2  new-york-524             1    2/6/2020
# 3  new-york-524             2   6/26/2019
# 4  new-york-524             1    3/3/2020
#
#                                          review_text  \
# 0  I've been to this Starbucks a handful of times...
# 1  Went in at 5:50 to make an order. This locatio...
# 2  Slowest Starbucks in the entire NYC (any borou...
# 3  My new office is around the corner from this l...
# 4  I sware if i can give this store 0 stars i wou...
#
#                                               image1  \
# 0                                                NaN
# 1                                                NaN
# 2  https://s3-media0.fl.yelpcdn.com/bphoto/VhQ2_T...
# 3  https://s3-media0.fl.yelpcdn.com/bphoto/ifxqLv...
# 4                                                NaN
#
#                                               image2 image3
# 0                                                NaN    NaN
# 1                                                NaN    NaN
# 2                                                NaN    NaN
# 3  https://s3-media0.fl.yelpcdn.com/bphoto/PBBja4...    NaN
# 4                                                NaN    NaN

# %%
## transform price levels to numbers
for i in range(len(information1)):
    if information1['price'][i] == '$':
        information1['price'][i] = 1
    elif information1['price'][i] == '$$':
        information1['price'][i] = 2
    elif information1['price'][i] == '$$$':
        information1['price'][i] = 3
    elif information1['price'][i] == '$$$$':
        information1['price'][i] = 4
    else:
        continue

information1.head()
# Out:
#        store_id       name        location      city  zip_code price  \
# 0  new-york-524        NaN             NaN       NaN       NaN   NaN
# 1  new-york-217  Starbucks     135 John St  New York   10038.0     1
# 2  new-york-567  Starbucks      80 Pine St  New York   10005.0     2
# 3  new-york-290  Starbucks      99 Wall St  New York   10005.0     1
# 4  new-york-381  Starbucks  100 William St  New York   10038.0     2
#
#        category  score  num_of_review
# 0           NaN    NaN            NaN
# 1  Coffee & Tea    2.5           47.0
# 2  Coffee & Tea    2.5           28.0
# 3  Coffee & Tea    2.5           39.0
# 4  Coffee & Tea    3.0           31.0

# %%
## add review_id
ids = pd.DataFrame(data = {'review_id': range(1, len(information2)+1)})
information2 = pd.concat([ids, information2], axis = 1)
information2.head()
# Out:
#    review_id      store_id  review_score review_time  \
# 0          1  new-york-524             2   10/6/2019
# 1          2  new-york-524             1  10/21/2019
# 2          3  new-york-524             1    2/6/2020
# 3          4  new-york-524             2   6/26/2019
# 4          5  new-york-524             1    3/3/2020
#
#                                          review_text  \
# 0  I've been to this Starbucks a handful of times...
# 1  Went in at 5:50 to make an order. This locatio...
# 2  Slowest Starbucks in the entire NYC (any borou...
# 3  My new office is around the corner from this l...
# 4  I sware if i can give this store 0 stars i wou...
#
#                                               image1  \
# 0                                                NaN
# 1                                                NaN
# 2  https://s3-media0.fl.yelpcdn.com/bphoto/VhQ2_T...
# 3  https://s3-media0.fl.yelpcdn.com/bphoto/ifxqLv...
# 4                                                NaN
#
#                                               image2 image3
# 0                                                NaN    NaN
# 1                                                NaN    NaN
# 2                                                NaN    NaN
# 3  https://s3-media0.fl.yelpcdn.com/bphoto/PBBja4...    NaN
# 4                                                NaN    NaN

# %%
## save two tables
information1.to_csv(r'information1.csv')
information2.to_csv(r'information2.csv')

# %% [markdown]
# # Import final table to MongoDB

# %%
import pymongo
import json
from bson.code import Code

# %%
myclient = pymongo.MongoClient("mongodb://localhost:27017/")

mydb = myclient["starbucks"]

mycol1 = mydb["store"]
mycol2 = mydb["review"]

# %%
## save two tables as json files
information1.to_json('starbucks_info1.json', orient = 'records', lines = True)
information2.to_json('starbucks_info2.json', orient = 'records', lines = True)

# %%
## insert store data
store_data = []
with open('starbucks_info1.json', 'r') as f:
    for line in f:
        store_data.append(json.loads(line))

mycol1.insert_many(store_data)

# %%
## insert review data
review_data = []
with open('starbucks_info2.json', 'r') as f:
    for line in f:
        review_data.append(json.loads(line))

mycol2.insert_many(review_data)

# %%
for x in mycol1.find().limit(25):
    print(x)
# Out:
# {'_id': ObjectId('5e689694dccfe72ce127ddb8'), 'store_id': 'new-york-524', 'name': None, 'location': None, 'city': None, 'zip_code': None, 'price': None, 'category': None, 'score': None, 'num_of_review': None}
# {'_id': ObjectId('5e689694dccfe72ce127ddb9'), 'store_id': 'new-york-217', 'name': 'Starbucks', 'location': '135 John St', 'city': 'New York', 'zip_code': 10038.0, 'price': 1, 'category': 'Coffee & Tea', 'score': 2.5, 'num_of_review': 47.0}
# {'_id': ObjectId('5e689694dccfe72ce127ddba'), 'store_id': 'new-york-567', 'name': 'Starbucks', 'location': '80 Pine St', 'city': 'New York', 'zip_code': 10005.0, 'price': 2, 'category': 'Coffee & Tea', 'score': 2.5, 'num_of_review': 28.0}
# {'_id': ObjectId('5e689694dccfe72ce127ddbb'), 'store_id': 'new-york-290', 'name': 'Starbucks', 'location': '99 Wall St', 'city': 'New York', 'zip_code': 10005.0, 'price': 1, 'category': 'Coffee & Tea', 'score': 2.5, 'num_of_review': 39.0}
# {'_id': ObjectId('5e689694dccfe72ce127ddbc'), 'store_id': 'new-york-381', 'name': 'Starbucks', 'location': '100 William St', 'city': 'New York', 'zip_code': 10038.0, 'price': 2, 'category': 'Coffee & Tea', 'score': 3.0, 'num_of_review': 31.0}
# {'_id': ObjectId('5e689694dccfe72ce127ddbd'), 'store_id': 'new-york-346', 'name': 'Starbucks', 'location': '60 Wall St', 'city': 'New York', 'zip_code': 10005.0, 'price': 2, 'category': 'Coffee & Tea', 'score': 3.0, 'num_of_review': 21.0}
# {'_id': ObjectId('5e689694dccfe72ce127ddbe'), 'store_id': 'new-york-506', 'name': 'Starbucks', 'location': '110 Pearl St', 'city': 'New York', 'zip_code': 10005.0, 'price': 2, 'category': 'Coffee & Tea', 'score': 2.0, 'num_of_review': 46.0}
# {'_id': ObjectId('5e689694dccfe72ce127ddbf'), 'store_id': 'new-york-395', 'name': 'Starbucks', 'location': '38 Park Row Ste 4', 'city': 'New York', 'zip_code': 10038.0, 'price': 1, 'category': 'Coffee & Tea', 'score': 3.0, 'num_of_review': 47.0}
# {'_id': ObjectId('5e689694dccfe72ce127ddc0'), 'store_id': 'new-york-214', 'name': 'Starbucks', 'location': '130 Fulton St', 'city': 'New York', 'zip_code': 10038.0, 'price': 1, 'category': 'Coffee & Tea', 'score': 3.5, 'num_of_review': 56.0}
# {'_id': ObjectId('5e689694dccfe72ce127ddc1'), 'store_id': 'new-york-404', 'name': 'Starbucks', 'location': '55 Liberty St', 'city': 'New York', 'zip_code': 10005.0, 'price': 2, 'category': 'Coffee & Tea', 'score': 2.5, 'num_of_review': 47.0}
# {'_id': ObjectId('5e689694dccfe72ce127ddc2'), 'store_id': 'new-york-229', 'name': 'Starbucks', 'location': '111 Worth St', 'city': 'New York', 'zip_code': 10013.0, 'price': 2, 'category': 'Coffee & Tea', 'score': 2.0, 'num_of_review': 44.0}
# {'_id': ObjectId('5e689694dccfe72ce127ddc3'), 'store_id': 'new-york-264', 'name': 'Starbucks', 'location': '233 Broadway', 'city': 'New York', 'zip_code': 10279.0, 'price': 1, 'category': 'Coffee & Tea', 'score': 2.0, 'num_of_review': 49.0}
# {'_id': ObjectId('5e689694dccfe72ce127ddc4'), 'store_id': 'new-york-143', 'name': 'Starbucks', 'location': '55 Broad St', 'city': 'New York', 'zip_code': 10004.0, 'price': 2, 'category': 'Coffee & Tea', 'score': 2.5, 'num_of_review': 82.0}
# {'_id': ObjectId('5e689694dccfe72ce127ddc5'), 'store_id': 'new-york-131', 'name': None, 'location': '55 Broad St', 'city': 'New York', 'zip_code': 10004.0, 'price': None, 'category': None, 'score': None, 'num_of_review': None}
# {'_id': ObjectId('5e689694dccfe72ce127ddc6'), 'store_id': 'new-york-295', 'name': 'Starbucks', 'location': '115 Broadway', 'city': 'New York', 'zip_code': 10006.0, 'price': 2, 'category': 'Coffee & Tea', 'score': 3.0, 'num_of_review': 44.0}
# {'_id': ObjectId('5e689694dccfe72ce127ddc7'), 'store_id': 'new-york-345', 'name': 'Starbucks', 'location': '195 Broadway', 'city': 'New York', 'zip_code': 10007.0, 'price': 2, 'category': 'Coffee & Tea', 'score': 2.5, 'num_of_review': 58.0}
# {'_id': ObjectId('5e689694dccfe72ce127ddc8'), 'store_id': 'new-york-278', 'name': 'Starbucks', 'location': '241 Canal St', 'city': 'New York', 'zip_code': 10013.0, 'price': 2, 'category': 'Coffee & Tea', 'score': 2.5, 'num_of_review': 106.0}
# {'_id': ObjectId('5e689694dccfe72ce127ddc9'), 'store_id': 'new-york-434', 'name': None, 'location': '241 Canal St', 'city': 'New York', 'zip_code': 10013.0, 'price': None, 'category': None, 'score': None, 'num_of_review': None}
# {'_id': ObjectId('5e689694dccfe72ce127ddca'), 'store_id': 'new-york-128', 'name': 'Starbucks', 'location': '120 Church St', 'city': 'New York', 'zip_code': 10007.0, 'price': 2, 'category': 'Coffee & Tea', 'score': 2.5, 'num_of_review': 61.0}
# {'_id': ObjectId('5e689694dccfe72ce127ddcb'), 'store_id': 'new-york-575', 'name': 'Starbucks', 'location': '55 Broadway', 'city': 'New York', 'zip_code': 10006.0, 'price': None, 'category': 'Coffee & Tea', 'score': 4.0, 'num_of_review': 8.0}
# {'_id': ObjectId('5e689694dccfe72ce127ddcc'), 'store_id': 'new-york-511', 'name': 'Starbucks', 'location': 'Two World Trade Center 33 Vesey St Loading Dock 2', 'city': 'New York', 'zip_code': 10007.0, 'price': 2, 'category': 'Coffee & Tea', 'score': 3.0, 'num_of_review': 27.0}
# {'_id': ObjectId('5e689694dccfe72ce127ddcd'), 'store_id': 'new-york-428', 'name': 'Starbucks', 'location': '80 Delancey St', 'city': 'New York', 'zip_code': 10002.0, 'price': 2, 'category': 'Coffee & Tea', 'score': 2.5, 'num_of_review': 137.0}
# {'_id': ObjectId('5e689694dccfe72ce127ddce'), 'store_id': 'new-york-574', 'name': 'Starbucks', 'location': '4 World Trade Ctr LL4350', 'city': 'New York', 'zip_code': 10007.0, 'price': None, 'category': 'Coffee & Tea', 'score': 4.0, 'num_of_review': 14.0}
# {'_id': ObjectId('5e689694dccfe72ce127ddcf'), 'store_id': 'new-york-189', 'name': 'Starbucks', 'location': '2 Broadway', 'city': 'New York', 'zip_code': 10004.0, 'price': 2, 'category': 'Coffee & Tea', 'score': 2.5, 'num_of_review': 68.0}
# {'_id': ObjectId('5e689694dccfe72ce127ddd0'), 'store_id': 'new-york-215', 'name': 'Starbucks', 'location': '405 Broadway', 'city': 'New York', 'zip_code': 10013.0, 'price': 1, 'category': 'Coffee & Tea', 'score': 3.0, 'num_of_review': 44.0}

# %%
for x in mycol2.find().limit(25):
    print(x)
# Out:
# {'_id': ObjectId('5e68627468650a075b110a74'), 'Unnamed: 0': 0, 'review_id': 1, 'store_id': 'seattle-340', 'review_score': 5, 'review_time': '10/3/2019', 'review_text': 'Lots of power strips for everyone with laptop. Not too busy. Next to lake union .Good place to relax or study or do work.', 'image1': 'https://s3-media0.fl.yelpcdn.com/bphoto/1cd7RTQ1DxUqCM0wFZa4rA/168s.jpg', 'image2': 'https://s3-media0.fl.yelpcdn.com/bphoto/q-Y8sPKOcy7x2-hU2793Zw/168s.jpg', 'image3': None, 'store_location': '515 Westlake Ave N', 'store_city': 'Seattle', 'store_zip_code': 98109.0, 'store_price_level': 1.0, 'store_category': 'Coffee & Tea', 'store_avg_score': 3.5, 'store_num_of_reviews': 17.0}
# {'_id': ObjectId('5e68627468650a075b110a75'), 'Unnamed: 0': 1, 'review_id': 2, 'store_id': 'seattle-340', 'review_score': 5, 'review_time': '9/8/2019', 'review_text': 'Great location in South Lake Union- Consistent drink quality for Starbucks, clean location and friendly staff. Located on the South Lake Union trolley line for easy access to make up for parking.', 'image1': None, 'image2': None, 'image3': None, 'store_location': '515 Westlake Ave N', 'store_city': 'Seattle', 'store_zip_code': 98109.0, 'store_price_level': 1.0, 'store_category': 'Coffee & Tea', 'store_avg_score': 3.5, 'store_num_of_reviews': 17.0}
# {'_id': ObjectId('5e68627468650a075b110a76'), 'Unnamed: 0': 2, 'review_id': 3, 'store_id': 'seattle-340', 'review_score': 4, 'review_time': '11/6/2018', 'review_text': 'Tried their seasonal specials after work. I had the caramel brûlée latte with nonfat milk and no whipped cream in Grande size. The Christmas theme cup was really cute. The Latte tasted good, and was perfect for a chilly day to warm myself up. I also noticed many gifts and seasonal cups and snacks, which were all attractive.', 'image1': 'https://s3-media0.fl.yelpcdn.com/bphoto/f6mUNM3YPP8KrdgJgTX69A/348s.jpg', 'image2': 'https://s3-media0.fl.yelpcdn.com/bphoto/omr6KRMtj6rVAmreFZjf2w/168s.jpg', 'image3': 'https://s3-media0.fl.yelpcdn.com/bphoto/P2MMzYJnUqj-d-GbJg_bbQ/168s.jpg', 'store_location': '515 Westlake Ave N', 'store_city': 'Seattle', 'store_zip_code': 98109.0, 'store_price_level': 1.0, 'store_category': 'Coffee & Tea', 'store_avg_score': 3.5, 'store_num_of_reviews': 17.0}
# {'_id': ObjectId('5e68627468650a075b110a77'), 'Unnamed: 0': 3, 'review_id': 4, 'store_id': 'seattle-340', 'review_score': 5, 'review_time': '4/2/2019', 'review_text': 'This places impressed me because they handled the high volume of Viaduct runner traffic. Not too shabby!', 'image1': None, 'image2': None, 'image3': None, 'store_location': '515 Westlake Ave N', 'store_city': 'Seattle', 'store_zip_code': 98109.0, 'store_price_level': 1.0, 'store_category': 'Coffee & Tea', 'store_avg_score': 3.5, 'store_num_of_reviews': 17.0}
# {'_id': ObjectId('5e68627468650a075b110a78'), 'Unnamed: 0': 4, 'review_id': 5, 'store_id': 'seattle-340', 'review_score': 5, 'review_time': '8/30/2018', 'review_text': "A series of unfortunate events brought me here, and it turned out to be a good stop on the way back up the hill to the office. This location is very spacious, and the service was quick. This store appears to be waiting for a modernization compared to the one further up the hill, but the look is still good and clean. Having never been to this location, I got exactly what I expected with no fuss. Their food selection here might be slightly higher than other smaller locations, but otherwise nothing super special here. Is it already PSL season? Please stop. I'm not ready.", 'image1': None, 'image2': None, 'image3': None, 'store_location': '515 Westlake Ave N', 'store_city': 'Seattle', 'store_zip_code': 98109.0, 'store_price_level': 1.0, 'store_category': 'Coffee & Tea', 'store_avg_score': 3.5, 'store_num_of_reviews': 17.0}
# {'_id': ObjectId('5e68627468650a075b110a79'), 'Unnamed: 0': 5, 'review_id': 6, 'store_id': 'seattle-340', 'review_score': 3, 'review_time': '8/1/2018', 'review_text': 'I try to avoid chains. But. I was overheated and needed a restroom. Bought a can of Spindrift, used the clean facilities and sat in a comfy chair to cool off and rejuvenate. The music was a bit loud and I was painting not trying to concentrate on anything needing verbal skills. If I needed to think it would have been difficult. Still, grateful for a place to cool off.', 'image1': None, 'image2': None, 'image3': None, 'store_location': '515 Westlake Ave N', 'store_city': 'Seattle', 'store_zip_code': 98109.0, 'store_price_level': 1.0, 'store_category': 'Coffee & Tea', 'store_avg_score': 3.5, 'store_num_of_reviews': 17.0}
# {'_id': ObjectId('5e68627468650a075b110a7a'), 'Unnamed: 0': 6, 'review_id': 7, 'store_id': 'seattle-340', 'review_score': 3, 'review_time': '12/14/2018', 'review_text': "You know I haven't been to a starbucks in Seattle in ten years. There are too many better options in this town that are truly local, original and better tasting.However, during a 5 minute break in a 5 hour string of meetings, I found myself needing a walk outside and a quick coffee. There is was, the Starbucks sign staring me right in the face. 2O years of market saturation and advertising zapped my tired brain with its defenses down...sure i'll just go here.You know what, it was just fine. It is exactly what it wants to be. No surprises, no highs and no lows. I got my coffee in the same 20 oz cup from 10 years ago, was given the same acceptable service...the soundtrack they were piping in the store was probably the same Michael Buble CD they were playing ten years ago too. The coffee was still Starbucks coffee...a little on the overdone side. But OK, if this is the level of middle of the road...the coffee drinking world is still doing OK.", 'image1': None, 'image2': None, 'image3': None, 'store_location': '515 Westlake Ave N', 'store_city': 'Seattle', 'store_zip_code': 98109.0, 'store_price_level': 1.0, 'store_category': 'Coffee & Tea', 'store_avg_score': 3.5, 'store_num_of_reviews': 17.0}
# {'_id': ObjectId('5e68627468650a075b110a7b'), 'Unnamed: 0': 7, 'review_id': 8, 'store_id': 'seattle-340', 'review_score': 3, 'review_time': '11/8/2018', 'review_text': "Good location near by bus stop. I was going to work here but place for work wasn't too much. Also was pretty loud inside. So I've spent about 30 minutes on the small table with my laptop and small latte and went out.", 'image1': None, 'image2': None, 'image3': None, 'store_location': '515 Westlake Ave N', 'store_city': 'Seattle', 'store_zip_code': 98109.0, 'store_price_level': 1.0, 'store_category': 'Coffee & Tea', 'store_avg_score': 3.5, 'store_num_of_reviews': 17.0}
# {'_id': ObjectId('5e68627468650a075b110a7c'), 'Unnamed: 0': 8, 'review_id': 9, 'store_id': 'seattle-340', 'review_score': 4, 'review_time': '10/27/2016', 'review_text': "As far as the cross streets are concerned, it's on the corner of the Mercer Mess and Westlake, so your view lookin outside mainly consists of cars attempt to drive in a manner that is not conducive to being part of the community. \xa0Once you get past that, inside is a very nicely built Starbucks, that fits the feel of the building.. the Amazon Building that is. Browns, and Wood grain everywhere make it feel homely, and cozy, with comfy chairs and tables for working/studying/gaming, time passes more quickly or slowly depending on your activity. I appreciate the quick work they do here, and the staff are markedly more awesome than superman saving a bunch of cats in a tree... because yes, they listen, they are friendly, and if you need it fast, they make your drink fast, and correctly. \xa0Yes Sir, this them are one fine establishment.", 'image1': 'https://s3-media0.fl.yelpcdn.com/bphoto/oQp3en0wlMPw4iDXq7-TkQ/348s.jpg', 'image2': None, 'image3': None, 'store_location': '515 Westlake Ave N', 'store_city': 'Seattle', 'store_zip_code': 98109.0, 'store_price_level': 1.0, 'store_category': 'Coffee & Tea', 'store_avg_score': 3.5, 'store_num_of_reviews': 17.0}
# {'_id': ObjectId('5e68627468650a075b110a7d'), 'Unnamed: 0': 9, 'review_id': 10, 'store_id': 'seattle-340', 'review_score': 1, 'review_time': '5/30/2019', 'review_text': "First time here and let's just say it will be my last. I hate dealing with crappy service, this place doesn't even say hello when you approach the counter to order let alone call your name to let you know the drink is ready... their workers (well more like one) didn't catch her name but they need to work on their customer service. Starbucks you're better than that.", 'image1': None, 'image2': None, 'image3': None, 'store_location': '515 Westlake Ave N', 'store_city': 'Seattle', 'store_zip_code': 98109.0, 'store_price_level': 1.0, 'store_category': 'Coffee & Tea', 'store_avg_score': 3.5, 'store_num_of_reviews': 17.0}
# {'_id': ObjectId('5e68627468650a075b110a7e'), 'Unnamed: 0': 10, 'review_id': 11, 'store_id': 'seattle-340', 'review_score': 5, 'review_time': '10/6/2016', 'review_text': 'Brand new Starbucks next to the Mercer Ave and Westlake Ave bus stop. \xa0Larger than your typical urban Starbucks with a sizeable working space. \xa0Standard selection of food and drink options. \xa0Friendly staff and clean bathrooms. \xa0Will be stopping in often after I get off the bus at the stop.', 'image1': 'https://s3-media0.fl.yelpcdn.com/bphoto/PWY5ORvV5gNMIHOBuwoI4g/168s.jpg', 'image2': 'https://s3-media0.fl.yelpcdn.com/bphoto/IyGMnOAS8IeGSLl1qBF8Nw/168s.jpg', 'image3': None, 'store_location': '515 Westlake Ave N', 'store_city': 'Seattle', 'store_zip_code': 98109.0, 'store_price_level': 1.0, 'store_category': 'Coffee & Tea', 'store_avg_score': 3.5, 'store_num_of_reviews': 17.0}
# {'_id': ObjectId('5e68627468650a075b110a7f'), 'Unnamed: 0': 11, 'review_id': 12, 'store_id': 'seattle-340', 'review_score': 2, 'review_time': '10/7/2018', 'review_text': 'NOT open at 5:30am. \xa0Sorry Starbucks, not everyone in this city has the fucking weekend off.', 'image1': None, 'image2': None, 'image3': None, 'store_location': '515 Westlake Ave N', 'store_city': 'Seattle', 'store_zip_code': 98109.0, 'store_price_level': 1.0, 'store_category': 'Coffee & Tea', 'store_avg_score': 3.5, 'store_num_of_reviews': 17.0}
# {'_id': ObjectId('5e68627468650a075b110a80'), 'Unnamed: 0': 12, 'review_id': 13, 'store_id': 'seattle-340', 'review_score': 3, 'review_time': '12/2/2016', 'review_text': 'Two reasons I was put off:-Middle management was having a snappy conversation with staff in front of the guests in line. \xa0Hard to tell if they were being short with staff or joking with a snarky tone. \xa0Kinda uncomfortable to witness. \xa0-Comfy armchairs are positioned WAY too close together and facing each other. \xa0Frankly, I felt sandwiched in with no sense of personal space. \xa0Why not line the chairs up, one group of four \xa0facing out the windows, a second group facing in towards the store? \xa0None facing or sharing arm space with a total stranger who is making weird slurpy noises with their drink? \xa0Ick.', 'image1': None, 'image2': None, 'image3': None, 'store_location': '515 Westlake Ave N', 'store_city': 'Seattle', 'store_zip_code': 98109.0, 'store_price_level': 1.0, 'store_category': 'Coffee & Tea', 'store_avg_score': 3.5, 'store_num_of_reviews': 17.0}
# {'_id': ObjectId('5e68627468650a075b110a81'), 'Unnamed: 0': 13, 'review_id': 14, 'store_id': 'seattle-340', 'review_score': 2, 'review_time': '1/22/2018', 'review_text': "Been consistently coming here for a year or so.Everyone is friendly and polite and a perfect mix of Seattle weird. (That's a great thing)...But watching the baristas smoke cigarettes 10 ft from the door on their breaks is gross. I don't want to walk through it to get in your store. Can you just go around back or something please?", 'image1': None, 'image2': None, 'image3': None, 'store_location': '515 Westlake Ave N', 'store_city': 'Seattle', 'store_zip_code': 98109.0, 'store_price_level': 1.0, 'store_category': 'Coffee & Tea', 'store_avg_score': 3.5, 'store_num_of_reviews': 17.0}
# {'_id': ObjectId('5e68627468650a075b110a82'), 'Unnamed: 0': 14, 'review_id': 15, 'store_id': 'seattle-340', 'review_score': 1, 'review_time': '1/20/2018', 'review_text': "Update: nope, still the worlds slowest Starbucks. Ordered ahead and still missed my bus because it's literally the most inefficiently rub Starbucks on the planet.", 'image1': None, 'image2': None, 'image3': None, 'store_location': '515 Westlake Ave N', 'store_city': 'Seattle', 'store_zip_code': 98109.0, 'store_price_level': 1.0, 'store_category': 'Coffee & Tea', 'store_avg_score': 3.5, 'store_num_of_reviews': 17.0}
# {'_id': ObjectId('5e68627468650a075b110a83'), 'Unnamed: 0': 15, 'review_id': 16, 'store_id': 'seattle-340', 'review_score': 5, 'review_time': '5/14/2017', 'review_text': "Great spot. It is designed to be more open and airy than other Starbucks stores with the idea that meetings will be conducted here. They have ample table space to conduct meetings and business. I've used it myself a couple of times. And of course it's right near the bus and monorail stop, has a view of MOHAI and Lake Union, has outdoor seating, good restrooms and great, consistent Starbucks service. I highly recommend this location and Starbucks in general for consistency, reliability, and quality. I am proud that another Starbucks store has joined the growing South Lake Union neighbourhood.", 'image1': None, 'image2': None, 'image3': None, 'store_location': '515 Westlake Ave N', 'store_city': 'Seattle', 'store_zip_code': 98109.0, 'store_price_level': 1.0, 'store_category': 'Coffee & Tea', 'store_avg_score': 3.5, 'store_num_of_reviews': 17.0}
# {'_id': ObjectId('5e68627468650a075b110a84'), 'Unnamed: 0': 16, 'review_id': 17, 'store_id': 'seattle-340', 'review_score': 5, 'review_time': '2/13/2017', 'review_text': 'My go to for my morning brew! The staff is always friendly and got my drink down to the tea. Always a good environment and a great place to do some afternoon work. The lobby is very spacious and I never feel crowded.', 'image1': None, 'image2': None, 'image3': None, 'store_location': '515 Westlake Ave N', 'store_city': 'Seattle', 'store_zip_code': 98109.0, 'store_price_level': 1.0, 'store_category': 'Coffee & Tea', 'store_avg_score': 3.5, 'store_num_of_reviews': 17.0}
# {'_id': ObjectId('5e68627468650a075b110a85'), 'Unnamed: 0': 17, 'review_id': 18, 'store_id': 'seattle-216', 'review_score': 5, 'review_time': '3/4/2019', 'review_text': 'Jay is great ,She works in the afternoon Jay has the best customer service I love when she is there and her barista skills are amazing. I wish she could teach the others how to make my drinks Thank You Jay for being a wonderful barista', 'image1': None, 'image2': None, 'image3': None, 'store_location': None, 'store_city': None, 'store_zip_code': None, 'store_price_level': 1.0, 'store_category': 'Coffee & Tea', 'store_avg_score': 4.0, 'store_num_of_reviews': 53.0}
# {'_id': ObjectId('5e68627468650a075b110a86'), 'Unnamed: 0': 18, 'review_id': 19, 'store_id': 'seattle-216', 'review_score': 1, 'review_time': '8/31/2019', 'review_text': "Every single time I go into this Starbucks and give them my name (Caroline), they always say Carolyn. This isn't just a single incident, this happens almost every time. I'm giving this Starbucks a 1 star because they don't take the time to get my name right. I even corrected the barista and she became spiteful and continued to call me Carolyn. What kind of customer service is this? Regarding my orders, the baristas usually do a good job.", 'image1': None, 'image2': None, 'image3': None, 'store_location': None, 'store_city': None, 'store_zip_code': None, 'store_price_level': 1.0, 'store_category': 'Coffee & Tea', 'store_avg_score': 4.0, 'store_num_of_reviews': 53.0}
# {'_id': ObjectId('5e68627468650a075b110a87'), 'Unnamed: 0': 19, 'review_id': 20, 'store_id': 'seattle-216', 'review_score': 4, 'review_time': '2/14/2019', 'review_text': "This Urban Starbucks is located right in the heart of Amazonia. Flanked by wood, brick, and concrete, this location is one of my favorites as there are usually a couple of parking spots right outside. \xa0There's always a diversified crowd in here. From people working on their laptops to construction workers, you will see pretty much everybody in here. I appreciate that they have lots of areas to plug in, when I'm looking to get some work done on my laptop. Of course, they offered in usual Austin variety of Starbucks drinks and food. Pro tip if you order on the app there is a 3-minute waiting so I'm right outside so you can run in and get your coffee.", 'image1': 'https://s3-media0.fl.yelpcdn.com/bphoto/bz94ent0Q4lsWOa21oj7Wg/348s.jpg', 'image2': 'https://s3-media0.fl.yelpcdn.com/bphoto/6yGjirfJ4yo1D2ED6Go9TQ/168s.jpg', 'image3': 'https://s3-media0.fl.yelpcdn.com/bphoto/VtuEh92zJNYTg1nLImv3SA/168s.jpg', 'store_location': None, 'store_city': None, 'store_zip_code': None, 'store_price_level': 1.0, 'store_category': 'Coffee & Tea', 'store_avg_score': 4.0, 'store_num_of_reviews': 53.0}
# {'_id': ObjectId('5e68627468650a075b110a88'), 'Unnamed: 0': 20, 'review_id': 21, 'store_id': 'seattle-216', 'review_score': 3, 'review_time': '10/31/2018', 'review_text': 'This is the Starbucks where all the fun people hang out apparently, or maybe it was just the 10/31 coincidence. This location is slightly larger than my usual destination, but it is great for meeting here, as there is ample seating compared to other nearby locations. The wifi there was either dead or dying, so I was unable to work remotely there since my cellular reception was also limited. Not sure if that is by design or by coincidence today, but I had to leave if I wanted to get anything done today. Coffee here is as nominal as any other Starbucks. Move along. Nothing special to see here.', 'image1': None, 'image2': None, 'image3': None, 'store_location': None, 'store_city': None, 'store_zip_code': None, 'store_price_level': 1.0, 'store_category': 'Coffee & Tea', 'store_avg_score': 4.0, 'store_num_of_reviews': 53.0}
# {'_id': ObjectId('5e68627468650a075b110a89'), 'Unnamed: 0': 21, 'review_id': 22, 'store_id': 'seattle-216', 'review_score': 3, 'review_time': '7/12/2019', 'review_text': "The location is convenient in South Lake Union as well as by my office right across the block. My reasoning for 3 stars is that the service is very hit or miss and the reason I continue to go is once again the convenience to my office. Some of the staff is amazing and polite and that is why the 3 stars. I like to think I'm a nice guy right? Saying good morning to staff, thanking them, and wishing them a good day. Normal stuff right? However on serval occasions my mobile order was not even announced as I watched the person look at my cup and just place it down to announce other people's coffee. I don't get why this happens with the same person every time. Maybe she has a complex with my name but who knows.*shoulder shrug* I use mobile order and place my order ten minutes ahead of time and when I arrive I have to wait another 15 minutes. My order is a simple venti black coffee with coconut milk. I have been given grande cups though charged for a venti. I do not say much when I'm in a hurry when this happens. I was sassed by a rude staff member by my order in a non peak hour as I received it cold. She said she would need to make more coffee so I could have a warm one. When I asked for a cup of ice so I can at least enjoy it another way that is when more sass came as she looked like I kicked her dog. Overall the experience is okay and if you need a convenient location for coffee and a free Amazon banana then go here.", 'image1': None, 'image2': None, 'image3': None, 'store_location': None, 'store_city': None, 'store_zip_code': None, 'store_price_level': 1.0, 'store_category': 'Coffee & Tea', 'store_avg_score': 4.0, 'store_num_of_reviews': 53.0}
# {'_id': ObjectId('5e68627468650a075b110a8a'), 'Unnamed: 0': 22, 'review_id': 23, 'store_id': 'seattle-216', 'review_score': 5, 'review_time': '7/30/2019', 'review_text': 'Speaking simply, this is the best Starbucks on earth. I have been coming here 3-4 times/day for the past 3+ years, and everyone is amazing. Candi, Gwen, Liz, Savannah, Jay, Jordan, Matan, etc. there are too many names to name. Everybody here is so friendly and most of the time they have my drink ready before I even reach the cash register. Best. Starbucks. Ever.', 'image1': None, 'image2': None, 'image3': None, 'store_location': None, 'store_city': None, 'store_zip_code': None, 'store_price_level': 1.0, 'store_category': 'Coffee & Tea', 'store_avg_score': 4.0, 'store_num_of_reviews': 53.0}
# {'_id': ObjectId('5e68627468650a075b110a8b'), 'Unnamed: 0': 23, 'review_id': 24, 'store_id': 'seattle-216', 'review_score': 4, 'review_time': '3/23/2018', 'review_text': "Prime location! Great location to have quick meetings for work or to catch up with friends. I come here quite often as it is right in the heart of the area where my office is. I would say the majority of the staff is great! Few that need some TLC, but most are amazingly friendly. \xa0The lines can get pretty massive as there are several Amazon buildings surrounding it. I would suggest if you're looking to come in between 8-9:30 you should mobile order! Otherwise the line can be fairly long. Great place in the summer to sit on their patio and people watch, as well as check out the farmer market right out front.", 'image1': None, 'image2': None, 'image3': None, 'store_location': None, 'store_city': None, 'store_zip_code': None, 'store_price_level': 1.0, 'store_category': 'Coffee & Tea', 'store_avg_score': 4.0, 'store_num_of_reviews': 53.0}
# {'_id': ObjectId('5e68627468650a075b110a8c'), 'Unnamed: 0': 24, 'review_id': 25, 'store_id': 'seattle-216', 'review_score': 4, 'review_time': '3/12/2017', 'review_text': "This is the main Starbucks on the Amazon campus in South Lake Union. It is located in the Cricket Building next to Veggie Grill. As it is the primary Starbucks in the area, it can get quite busy. There is actually another Starbucks down the street on Westlake Avenue in the building housing Microsoft, but that one isn't as crowded. That said, it doesn't offer as many features as this location.Here you will find outdoor seating along with a comfortable amount of inside seating. There is some nook seating in the back of the store if you want a quiet place to get some work done. Until the program was discontinued, this was one of the stores that offer Starbucks Evenings menu items. Still, this store is the one to go to if you are looking for Starbucks Reserve and Clover brewed coffees.Although this location can get busy, the wait for my drink is most of the time not too long. If you want a better quality drink, I would go to this location over the one on Westlake. Visiting this location also gives me a reason to grab a banana at the Amazon Community Banana Stand next door to eat with my workday coffee.", 'image1': 'https://s3-media0.fl.yelpcdn.com/bphoto/_frbeRB3Tk-Guws3JwH6eQ/348s.jpg', 'image2': 'https://s3-media0.fl.yelpcdn.com/bphoto/bXOaLdXsk4n3okdpzBfkGQ/168s.jpg', 'image3': 'https://s3-media0.fl.yelpcdn.com/bphoto/Lhw6ikwJgXnoe2xG-HaoAw/168s.jpg', 'store_location': None, 'store_city': None, 'store_zip_code': None, 'store_price_level': 1.0, 'store_category': 'Coffee & Tea', 'store_avg_score': 4.0, 'store_num_of_reviews': 53.0}
